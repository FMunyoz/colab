# %% [markdown]
# <h1><font color="#113D68" size=6>Deep Learning con Python y Keras</font></h1>
#
# <h1><font color="#113D68" size=5>Parte 4. MLP avanzado</font></h1>
#
# <h1><font color="#113D68" size=4>2. Verificar el entrenamiento</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#113D68" size=3>Manuel Castillo Cara</font><br>
#
# </div>

# %% [markdown]
# ---
#
# <a id="indice"></a>
# <h2><font color="#004D7F" size=5>Índice</font></h2>
#
# * [0. Contexto](#section0)
# * [1. Introducción](#section1)
# * [2. Punto de control en el modelo](#section2)
# * [3. Punto de control en el mejor modelo](#section3)
# * [4. Cargar un modelo guardado](#section4)

# %% [markdown]
# ---
# <a id="section0"></a>
# # <font color="#004D7F" size=6> 0. Contexto</font>

# %% [markdown]
# En esta lección, descubrirá cómo puede verificar los modelos durante el entrenamiento. Después de completar esta lección, sabrá:
# * La importancia de verificar los modelos durante el entrenamiento.
# * Cómo verificar cada mejora durante el entrenamiento.
# * Cómo verificar el mejor modelo durante el entrenamiento.

# %%
import tensorflow as tf
# Eliminar warning
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section1"></a>
# # <font color="#004D7F" size=6>1. Introducción</font>

# %% [markdown]
# El punto de control puede usarse directamente o usarse como punto de partida para una nueva ejecución, retomando donde lo dejamos. Al entrenar modelos de aprendizaje profundo, el punto de control captura los pesos del modelo.
#
# La clase `ModelCheckpoint` permite definir dónde controlar los pesos del modelo, cómo se debe nombrar el archivo y bajo qué circunstancias hacer un punto de control del modelo.
#
# La instancia de `ModelCheckpoint` se puede pasar al proceso de entrenamiento al llamar a la función `fit()` en el modelo (Se deberá instalar `h5py`).

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section2"></a>
# # <font color="#004D7F" size=6>2. Punto de control en el modelo</font>

# %% [markdown]
# Los puntos de control están configurados para guardar los pesos de la red solo cuando hay una **mejora** en el Accuracy (`monitor = 'val_accuracy'` y `mode = 'max')`.
#
# Los pesos se almacenan en un archivo que incluye la puntuación en el nombre de archivo `weights-improvement-epoch-val accuracy=.2f.hdf5`.

# %%
# Checkpoint the weights when validation accuracy improves
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import numpy as np

# load pima indians dataset
dataset = np.loadtxt("https://raw.githubusercontent.com/FMunyoz/colab/main/Datasets/pima-indians-diabetes.csv", delimiter=',')

# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
y = dataset[:, 8]

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# checkpoint
filepath = 'weights-improvement-{epoch:02d}-{val_accuracy:0.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Fit the model
model.fit(X, y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.55906, saving model to weights-improvement-01-0.56.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.55906
#
# Epoch 00003: val_accuracy did not improve from 0.55906
#
# Epoch 00004: val_accuracy improved from 0.55906 to 0.56693, saving model to weights-improvement-04-0.57.hdf5
#
# Epoch 00005: val_accuracy did not improve from 0.56693
#
# Epoch 00006: val_accuracy did not improve from 0.56693
#
# Epoch 00007: val_accuracy improved from 0.56693 to 0.59055, saving model to weights-improvement-07-0.59.hdf5
#
# Epoch 00008: val_accuracy improved from 0.59055 to 0.59449, saving model to weights-improvement-08-0.59.hdf5
#
# Epoch 00009: val_accuracy did not improve from 0.59449
#
# Epoch 00010: val_accuracy did not improve from 0.59449
#
# Epoch 00011: val_accuracy did not improve from 0.59449
#
# Epoch 00012: val_accuracy did not improve from 0.59449
#
# Epoch 00013: val_accuracy improved from 0.59449 to 0.61811, saving model to weights-improvement-13-0.62.hdf5
#
# Epoch 00014: val_accuracy did not improve from 0.61811
#
# Epoch 00015: val_accuracy did not improve from 0.61811
#
# Epoch 00016: val_accuracy did not improve from 0.61811
#
# Epoch 00017: val_accuracy did not improve from 0.61811
#
# Epoch 00018: val_accuracy did not improve from 0.61811
#
# Epoch 00019: val_accuracy did not improve from 0.61811
#
# Epoch 00020: val_accuracy did not improve from 0.61811
#
# Epoch 00021: val_accuracy did not improve from 0.61811
#
# Epoch 00022: val_accuracy did not improve from 0.61811
#
# Epoch 00023: val_accuracy did not improve from 0.61811
#
# Epoch 00024: val_accuracy did not improve from 0.61811
#
# Epoch 00025: val_accuracy did not improve from 0.61811
#
# Epoch 00026: val_accuracy did not improve from 0.61811
#
# Epoch 00027: val_accuracy did not improve from 0.61811
#
# Epoch 00028: val_accuracy did not improve from 0.61811
#
# Epoch 00029: val_accuracy did not improve from 0.61811
#
# Epoch 00030: val_accuracy did not improve from 0.61811
#
# Epoch 00031: val_accuracy did not improve from 0.61811
#
# Epoch 00032: val_accuracy did not improve from 0.61811
#
# Epoch 00033: val_accuracy did not improve from 0.61811
#
# Epoch 00034: val_accuracy did not improve from 0.61811
#
# Epoch 00035: val_accuracy improved from 0.61811 to 0.62205, saving model to weights-improvement-35-0.62.hdf5
#
# Epoch 00036: val_accuracy did not improve from 0.62205
#
# Epoch 00037: val_accuracy did not improve from 0.62205
#
# Epoch 00038: val_accuracy did not improve from 0.62205
#
# Epoch 00039: val_accuracy improved from 0.62205 to 0.62598, saving model to weights-improvement-39-0.63.hdf5
#
# Epoch 00040: val_accuracy did not improve from 0.62598
#
# Epoch 00041: val_accuracy did not improve from 0.62598
#
# Epoch 00042: val_accuracy improved from 0.62598 to 0.62992, saving model to weights-improvement-42-0.63.hdf5
#
# Epoch 00043: val_accuracy improved from 0.62992 to 0.65354, saving model to weights-improvement-43-0.65.hdf5
#
# Epoch 00044: val_accuracy did not improve from 0.65354
#
# Epoch 00045: val_accuracy did not improve from 0.65354
#
# Epoch 00046: val_accuracy did not improve from 0.65354
#
# Epoch 00047: val_accuracy did not improve from 0.65354
#
# Epoch 00048: val_accuracy did not improve from 0.65354
#
# Epoch 00049: val_accuracy did not improve from 0.65354
#
# Epoch 00050: val_accuracy did not improve from 0.65354
#
# Epoch 00051: val_accuracy did not improve from 0.65354
#
# Epoch 00052: val_accuracy did not improve from 0.65354
#
# Epoch 00053: val_accuracy did not improve from 0.65354
#
# Epoch 00054: val_accuracy did not improve from 0.65354
#
# Epoch 00055: val_accuracy did not improve from 0.65354
#
# Epoch 00056: val_accuracy did not improve from 0.65354
#
# Epoch 00057: val_accuracy did not improve from 0.65354
#
# Epoch 00058: val_accuracy improved from 0.65354 to 0.65748, saving model to weights-improvement-58-0.66.hdf5
#
# Epoch 00059: val_accuracy improved from 0.65748 to 0.68110, saving model to weights-improvement-59-0.68.hdf5
#
# Epoch 00060: val_accuracy did not improve from 0.68110
#
# Epoch 00061: val_accuracy did not improve from 0.68110
#
# Epoch 00062: val_accuracy did not improve from 0.68110
#
# Epoch 00063: val_accuracy did not improve from 0.68110
#
# Epoch 00064: val_accuracy did not improve from 0.68110
#
# Epoch 00065: val_accuracy did not improve from 0.68110
#
# Epoch 00066: val_accuracy did not improve from 0.68110
#
# Epoch 00067: val_accuracy did not improve from 0.68110
#
# Epoch 00068: val_accuracy did not improve from 0.68110
#
# Epoch 00069: val_accuracy did not improve from 0.68110
#
# Epoch 00070: val_accuracy did not improve from 0.68110
#
# Epoch 00071: val_accuracy did not improve from 0.68110
#
# Epoch 00072: val_accuracy did not improve from 0.68110
#
# Epoch 00073: val_accuracy did not improve from 0.68110
#
# Epoch 00074: val_accuracy did not improve from 0.68110
#
# Epoch 00075: val_accuracy did not improve from 0.68110
#
# Epoch 00076: val_accuracy did not improve from 0.68110
#
# Epoch 00077: val_accuracy did not improve from 0.68110
#
# Epoch 00078: val_accuracy did not improve from 0.68110
#
# Epoch 00079: val_accuracy did not improve from 0.68110
#
# Epoch 00080: val_accuracy did not improve from 0.68110
#
# Epoch 00081: val_accuracy did not improve from 0.68110
#
# Epoch 00082: val_accuracy did not improve from 0.68110
#
# Epoch 00083: val_accuracy did not improve from 0.68110
#
# Epoch 00084: val_accuracy did not improve from 0.68110
#
# Epoch 00085: val_accuracy did not improve from 0.68110
#
# Epoch 00086: val_accuracy did not improve from 0.68110
#
# Epoch 00087: val_accuracy improved from 0.68110 to 0.70866, saving model to weights-improvement-87-0.71.hdf5
#
# Epoch 00088: val_accuracy improved from 0.70866 to 0.71260, saving model to weights-improvement-88-0.71.hdf5
#
# Epoch 00089: val_accuracy did not improve from 0.71260
#
# Epoch 00090: val_accuracy did not improve from 0.71260
#
# Epoch 00091: val_accuracy did not improve from 0.71260
#
# Epoch 00092: val_accuracy did not improve from 0.71260
#
# Epoch 00093: val_accuracy did not improve from 0.71260
#
# Epoch 00094: val_accuracy did not improve from 0.71260
#
# Epoch 00095: val_accuracy did not improve from 0.71260
#
# Epoch 00096: val_accuracy did not improve from 0.71260
#
# Epoch 00097: val_accuracy did not improve from 0.71260
#
# Epoch 00098: val_accuracy did not improve from 0.71260
#
# Epoch 00099: val_accuracy did not improve from 0.71260
#
# Epoch 00100: val_accuracy did not improve from 0.71260
#
# Epoch 00101: val_accuracy did not improve from 0.71260
#
# Epoch 00102: val_accuracy did not improve from 0.71260
#
# Epoch 00103: val_accuracy did not improve from 0.71260
#
# Epoch 00104: val_accuracy did not improve from 0.71260
#
# Epoch 00105: val_accuracy did not improve from 0.71260
#
# Epoch 00106: val_accuracy did not improve from 0.71260
#
# Epoch 00107: val_accuracy did not improve from 0.71260
#
# Epoch 00108: val_accuracy did not improve from 0.71260
#
# Epoch 00109: val_accuracy did not improve from 0.71260
#
# Epoch 00110: val_accuracy did not improve from 0.71260
#
# Epoch 00111: val_accuracy did not improve from 0.71260
#
# Epoch 00112: val_accuracy did not improve from 0.71260
#
# Epoch 00113: val_accuracy did not improve from 0.71260
#
# Epoch 00114: val_accuracy did not improve from 0.71260
#
# Epoch 00115: val_accuracy did not improve from 0.71260
#
# Epoch 00116: val_accuracy did not improve from 0.71260
#
# Epoch 00117: val_accuracy did not improve from 0.71260
#
# Epoch 00118: val_accuracy did not improve from 0.71260
#
# Epoch 00119: val_accuracy did not improve from 0.71260
#
# Epoch 00120: val_accuracy did not improve from 0.71260
#
# Epoch 00121: val_accuracy did not improve from 0.71260
#
# Epoch 00122: val_accuracy did not improve from 0.71260
#
# Epoch 00123: val_accuracy did not improve from 0.71260
#
# Epoch 00124: val_accuracy improved from 0.71260 to 0.73228, saving model to weights-improvement-124-0.73.hdf5
#
# Epoch 00125: val_accuracy did not improve from 0.73228
#
# Epoch 00126: val_accuracy did not improve from 0.73228
#
# Epoch 00127: val_accuracy did not improve from 0.73228
#
# Epoch 00128: val_accuracy did not improve from 0.73228
#
# Epoch 00129: val_accuracy did not improve from 0.73228
#
# Epoch 00130: val_accuracy did not improve from 0.73228
#
# Epoch 00131: val_accuracy did not improve from 0.73228
#
# Epoch 00132: val_accuracy did not improve from 0.73228
#
# Epoch 00133: val_accuracy did not improve from 0.73228
#
# Epoch 00134: val_accuracy did not improve from 0.73228
#
# Epoch 00135: val_accuracy did not improve from 0.73228
#
# Epoch 00136: val_accuracy did not improve from 0.73228
#
# Epoch 00137: val_accuracy did not improve from 0.73228
#
# Epoch 00138: val_accuracy did not improve from 0.73228
#
# Epoch 00139: val_accuracy did not improve from 0.73228
#
# Epoch 00140: val_accuracy did not improve from 0.73228
#
# Epoch 00141: val_accuracy did not improve from 0.73228
#
# Epoch 00142: val_accuracy did not improve from 0.73228
#
# Epoch 00143: val_accuracy did not improve from 0.73228
#
# Epoch 00144: val_accuracy did not improve from 0.73228
#
# Epoch 00145: val_accuracy did not improve from 0.73228
#
# Epoch 00146: val_accuracy did not improve from 0.73228
#
# Epoch 00147: val_accuracy did not improve from 0.73228
#
# Epoch 00148: val_accuracy did not improve from 0.73228
#
# Epoch 00149: val_accuracy did not improve from 0.73228
#
# Epoch 00150: val_accuracy did not improve from 0.73228

# %% [markdown]
# Ejecutar el ejemplo produce el resultado siguiente, truncado por brevedad. También verá una serie de archivos en su directorio de trabajo que contienen los pesos de red en formato HDF5. Por ejemplo:
# ```
#     weights-improvement-01-0.59.hdf5
#     weights-improvement-02-0.60.hdf5
# ```

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section3"></a>
# # <font color="#004D7F" size=6>3. Punto de control en el mejor modelo</font>

# %% [markdown]
# En este caso, los pesos del modelo se escriben en el archivo `weights.best.hdf5` solo si el Accuracy de clasificación del modelo en el conjunto de datos de validación mejora.

# %%
# Checkpoint the weights when validation accuracy improves
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import numpy as np

# load pima indians dataset
dataset = np.loadtxt("https://raw.githubusercontent.com/FMunyoz/colab/main/Datasets/pima-indians-diabetes.csv", delimiter=',')

# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
y = dataset[:, 8]

# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# checkpoint
filepath = 'weights-best.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Fit the model
model.fit(X, y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.47638, saving model to weights-best.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.47638
#
# Epoch 00003: val_accuracy did not improve from 0.47638
#
# Epoch 00004: val_accuracy did not improve from 0.47638
#
# Epoch 00005: val_accuracy improved from 0.47638 to 0.55512, saving model to weights-best.hdf5
#
# Epoch 00006: val_accuracy did not improve from 0.55512
#
# Epoch 00007: val_accuracy did not improve from 0.55512
#
# Epoch 00008: val_accuracy improved from 0.55512 to 0.58661, saving model to weights-best.hdf5
#
# Epoch 00009: val_accuracy improved from 0.58661 to 0.62598, saving model to weights-best.hdf5
#
# Epoch 00010: val_accuracy did not improve from 0.62598
#
# Epoch 00011: val_accuracy did not improve from 0.62598
#
# Epoch 00012: val_accuracy did not improve from 0.62598
#
# Epoch 00013: val_accuracy did not improve from 0.62598
#
# Epoch 00014: val_accuracy did not improve from 0.62598
#
# Epoch 00015: val_accuracy did not improve from 0.62598
#
# Epoch 00016: val_accuracy did not improve from 0.62598
#
# Epoch 00017: val_accuracy did not improve from 0.62598
#
# Epoch 00018: val_accuracy did not improve from 0.62598
#
# Epoch 00019: val_accuracy did not improve from 0.62598
#
# Epoch 00020: val_accuracy improved from 0.62598 to 0.63386, saving model to weights-best.hdf5
#
# Epoch 00021: val_accuracy did not improve from 0.63386
#
# Epoch 00022: val_accuracy did not improve from 0.63386
#
# Epoch 00023: val_accuracy did not improve from 0.63386
#
# Epoch 00024: val_accuracy did not improve from 0.63386
#
# Epoch 00025: val_accuracy improved from 0.63386 to 0.65354, saving model to weights-best.hdf5
#
# Epoch 00026: val_accuracy did not improve from 0.65354
#
# Epoch 00027: val_accuracy did not improve from 0.65354
#
# Epoch 00028: val_accuracy did not improve from 0.65354
#
# Epoch 00029: val_accuracy did not improve from 0.65354
#
# Epoch 00030: val_accuracy did not improve from 0.65354
#
# Epoch 00031: val_accuracy did not improve from 0.65354
#
# Epoch 00032: val_accuracy did not improve from 0.65354
#
# Epoch 00033: val_accuracy did not improve from 0.65354
#
# Epoch 00034: val_accuracy did not improve from 0.65354
#
# Epoch 00035: val_accuracy did not improve from 0.65354
#
# Epoch 00036: val_accuracy did not improve from 0.65354
#
# Epoch 00037: val_accuracy did not improve from 0.65354
#
# Epoch 00038: val_accuracy did not improve from 0.65354
#
# Epoch 00039: val_accuracy did not improve from 0.65354
#
# Epoch 00040: val_accuracy did not improve from 0.65354
#
# Epoch 00041: val_accuracy did not improve from 0.65354
#
# Epoch 00042: val_accuracy did not improve from 0.65354
#
# Epoch 00043: val_accuracy did not improve from 0.65354
#
# Epoch 00044: val_accuracy did not improve from 0.65354
#
# Epoch 00045: val_accuracy did not improve from 0.65354
#
# Epoch 00046: val_accuracy did not improve from 0.65354
#
# Epoch 00047: val_accuracy did not improve from 0.65354
#
# Epoch 00048: val_accuracy did not improve from 0.65354
#
# Epoch 00049: val_accuracy did not improve from 0.65354
#
# Epoch 00050: val_accuracy improved from 0.65354 to 0.65748, saving model to weights-best.hdf5
#
# Epoch 00051: val_accuracy did not improve from 0.65748
#
# Epoch 00052: val_accuracy did not improve from 0.65748
#
# Epoch 00053: val_accuracy did not improve from 0.65748
#
# Epoch 00054: val_accuracy did not improve from 0.65748
#
# Epoch 00055: val_accuracy improved from 0.65748 to 0.68110, saving model to weights-best.hdf5
#
# Epoch 00056: val_accuracy did not improve from 0.68110
#
# Epoch 00057: val_accuracy did not improve from 0.68110
#
# Epoch 00058: val_accuracy did not improve from 0.68110
#
# Epoch 00059: val_accuracy did not improve from 0.68110
#
# Epoch 00060: val_accuracy did not improve from 0.68110
#
# Epoch 00061: val_accuracy did not improve from 0.68110
#
# Epoch 00062: val_accuracy did not improve from 0.68110
#
# Epoch 00063: val_accuracy did not improve from 0.68110
#
# Epoch 00064: val_accuracy did not improve from 0.68110
#
# Epoch 00065: val_accuracy did not improve from 0.68110
#
# Epoch 00066: val_accuracy did not improve from 0.68110
#
# Epoch 00067: val_accuracy did not improve from 0.68110
#
# Epoch 00068: val_accuracy did not improve from 0.68110
#
# Epoch 00069: val_accuracy did not improve from 0.68110
#
# Epoch 00070: val_accuracy did not improve from 0.68110
#
# Epoch 00071: val_accuracy did not improve from 0.68110
#
# Epoch 00072: val_accuracy did not improve from 0.68110
#
# Epoch 00073: val_accuracy did not improve from 0.68110
#
# Epoch 00074: val_accuracy did not improve from 0.68110
#
# Epoch 00075: val_accuracy did not improve from 0.68110
#
# Epoch 00076: val_accuracy did not improve from 0.68110
#
# Epoch 00077: val_accuracy did not improve from 0.68110
#
# Epoch 00078: val_accuracy did not improve from 0.68110
#
# Epoch 00079: val_accuracy did not improve from 0.68110
#
# Epoch 00080: val_accuracy did not improve from 0.68110
#
# Epoch 00081: val_accuracy did not improve from 0.68110
#
# Epoch 00082: val_accuracy did not improve from 0.68110
#
# Epoch 00083: val_accuracy did not improve from 0.68110
#
# Epoch 00084: val_accuracy did not improve from 0.68110
#
# Epoch 00085: val_accuracy did not improve from 0.68110
#
# Epoch 00086: val_accuracy did not improve from 0.68110
#
# Epoch 00087: val_accuracy did not improve from 0.68110
#
# Epoch 00088: val_accuracy did not improve from 0.68110
#
# Epoch 00089: val_accuracy improved from 0.68110 to 0.69291, saving model to weights-best.hdf5
#
# Epoch 00090: val_accuracy did not improve from 0.69291
#
# Epoch 00091: val_accuracy did not improve from 0.69291
#
# Epoch 00092: val_accuracy did not improve from 0.69291
#
# Epoch 00093: val_accuracy did not improve from 0.69291
#
# Epoch 00094: val_accuracy did not improve from 0.69291
#
# Epoch 00095: val_accuracy did not improve from 0.69291
#
# Epoch 00096: val_accuracy did not improve from 0.69291
#
# Epoch 00097: val_accuracy did not improve from 0.69291
#
# Epoch 00098: val_accuracy did not improve from 0.69291
#
# Epoch 00099: val_accuracy did not improve from 0.69291
#
# Epoch 00100: val_accuracy did not improve from 0.69291
#
# Epoch 00101: val_accuracy did not improve from 0.69291
#
# Epoch 00102: val_accuracy did not improve from 0.69291
#
# Epoch 00103: val_accuracy did not improve from 0.69291
#
# Epoch 00104: val_accuracy did not improve from 0.69291
#
# Epoch 00105: val_accuracy did not improve from 0.69291
#
# Epoch 00106: val_accuracy did not improve from 0.69291
#
# Epoch 00107: val_accuracy did not improve from 0.69291
#
# Epoch 00108: val_accuracy did not improve from 0.69291
#
# Epoch 00109: val_accuracy did not improve from 0.69291
#
# Epoch 00110: val_accuracy did not improve from 0.69291
#
# Epoch 00111: val_accuracy did not improve from 0.69291
#
# Epoch 00112: val_accuracy did not improve from 0.69291
#
# Epoch 00113: val_accuracy did not improve from 0.69291
#
# Epoch 00114: val_accuracy did not improve from 0.69291
#
# Epoch 00115: val_accuracy did not improve from 0.69291
#
# Epoch 00116: val_accuracy did not improve from 0.69291
#
# Epoch 00117: val_accuracy did not improve from 0.69291
#
# Epoch 00118: val_accuracy did not improve from 0.69291
#
# Epoch 00119: val_accuracy did not improve from 0.69291
#
# Epoch 00120: val_accuracy did not improve from 0.69291
#
# Epoch 00121: val_accuracy improved from 0.69291 to 0.70866, saving model to weights-best.hdf5
#
# Epoch 00122: val_accuracy did not improve from 0.70866
#
# Epoch 00123: val_accuracy did not improve from 0.70866
#
# Epoch 00124: val_accuracy did not improve from 0.70866
#
# Epoch 00125: val_accuracy did not improve from 0.70866
#
# Epoch 00126: val_accuracy did not improve from 0.70866
#
# Epoch 00127: val_accuracy did not improve from 0.70866
#
# Epoch 00128: val_accuracy did not improve from 0.70866
#
# Epoch 00129: val_accuracy did not improve from 0.70866
#
# Epoch 00130: val_accuracy did not improve from 0.70866
#
# Epoch 00131: val_accuracy did not improve from 0.70866
#
# Epoch 00132: val_accuracy did not improve from 0.70866
#
# Epoch 00133: val_accuracy did not improve from 0.70866
#
# Epoch 00134: val_accuracy did not improve from 0.70866
#
# Epoch 00135: val_accuracy did not improve from 0.70866
#
# Epoch 00136: val_accuracy did not improve from 0.70866
#
# Epoch 00137: val_accuracy did not improve from 0.70866
#
# Epoch 00138: val_accuracy did not improve from 0.70866
#
# Epoch 00139: val_accuracy did not improve from 0.70866
#
# Epoch 00140: val_accuracy did not improve from 0.70866
#
# Epoch 00141: val_accuracy improved from 0.70866 to 0.71260, saving model to weights-best.hdf5
#
# Epoch 00142: val_accuracy did not improve from 0.71260
#
# Epoch 00143: val_accuracy improved from 0.71260 to 0.72441, saving model to weights-best.hdf5
#
# Epoch 00144: val_accuracy did not improve from 0.72441
#
# Epoch 00145: val_accuracy did not improve from 0.72441
#
# Epoch 00146: val_accuracy did not improve from 0.72441
#
# Epoch 00147: val_accuracy did not improve from 0.72441
#
# Epoch 00148: val_accuracy did not improve from 0.72441
#
# Epoch 00149: val_accuracy did not improve from 0.72441
#
# Epoch 00150: val_accuracy did not improve from 0.72441

# %% [markdown]
# Debería ver el archivo de peso en su directorio local.
# ```
#     weights.best.hdf5
# ```

# %% [markdown]
# <a id="section4"></a>
# # <font color="#004D7F" size=6>4. Cargar un modelo guardado</font>

# %% [markdown]
# En el siguiente ejemplo, se conoce la estructura del modelo y los mejores pesos se cargan del experimento anterior, almacenados en el directorio de trabajo en el archivo `weights.best.hdf5`.
#
# Luego, el modelo se usa para hacer predicciones en todo el conjunto de datos.

# %%
# How to load and use weights from a checkpoint

from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# create model

model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# load weights
model.load_weights('weights-best.hdf5')

# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Modelo creado con pesos del fichero")
# load pima indians dataset
dataset = np.loadtxt("https://raw.githubusercontent.com/FMunyoz/colab/main/Datasets/pima-indians-diabetes.csv", delimiter=',')

# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
y = dataset[:, 8]

# estimate accuracy on whole dataset using loaded weights
scores=model.evaluate(X, y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Modelo creado con pesos del fichero
# accuracy: 74.87%

# %% [markdown]
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---
#
# <div style="text-align: right"> <font size=6><i class="fa fa-coffee" aria-hidden="true" style="color:#004D7F"></i> </font></div>
